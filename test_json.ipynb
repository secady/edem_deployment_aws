# %%
import pandas as pd
import json

# %%
with open("Scrap/startups_by_rows.json", "r") as file:
    result = json.load(file)

result
# Out:
# {'0': {'name': 'Mytapper',
#   'phase': 'Growth',
#   'topics': ['alimentación', 'Delivery'],
#   'description': 'Mytapper permite pedir comida desde casa o desde el propio restaurante.',
#   'url': 'https://lanzadera.es/proyecto/mytapper/',
#   'logo_link': 'https://lanzadera.es/wp-content/uploads/2023/05/Mytapper_logo_04-2023-removebg-preview.png'},
#  '1': {'name': 'Beawre',
#   'phase': 'Traction',
#   'topics': ['construcción', 'Inteligencia Artificial'],
#   'description': 'Controla riesgos sobre procesos de negocio en tiempo real',
#   'url': 'https://lanzadera.es/proyecto/beawre/',
#   'logo_link': 'https://lanzadera.es/wp-content/uploads/2023/05/Beawre_logo1_420x420.png'},
#  '2': {'name': 'Sitandplug ',
#   'phase': 'Growth',
#   'topics': ['Digital', 'Software'],
#   'description': 'Sitandplug es un marketplace de oficinas y espacios de trabajo flexibles con…',
#   'url': 'https://lanzadera.es/proyecto/sitandplug/',
# ...

# %%
startups_df = pd.read_json("Scrap\startups_data.json")
startups_df
# Out:
#                    name     phase
# 0              Mytapper    Growth  \
# 1                Beawre  Traction
# 2           Sitandplug     Growth
# 3            LIIFFE APP  Traction
# 4       Mundoestudiante  Scale up
# ..                  ...       ...
# 755  ESCUELA DE CIENCIA    Growth
# 756              EKUORE    Growth
# 757      DENTAL DOCTORS      None
# 758           CODIGAMES    Growth
# 759               BYOM!  Traction
#
#                                                topics
# 0                            [alimentación, Delivery]  \
# 1             [construcción, Inteligencia Artificial]
# 2                                 [Digital, Software]
# 3                         [Economía circular, Viajes]
# 4                       [E-Learining, Impacto social]
# ..                                                ...
# 755  [Customer experience, Nuevas formas de conectar]
# 756    [Digitalización, Diseño, Productos saludables]
# 757                                              None
# ...

# %%
startups_df.to_dict(orient="index")
# Out:
# {0: {'name': 'Mytapper',
#   'phase': 'Growth',
#   'topics': ['alimentación', 'Delivery'],
#   'description': 'Mytapper permite pedir comida desde casa o desde el propio restaurante.',
#   'url': 'https://lanzadera.es/proyecto/mytapper/',
#   'logo_link': 'https://lanzadera.es/wp-content/uploads/2023/05/Mytapper_logo_04-2023-removebg-preview.png'},
#  1: {'name': 'Beawre',
#   'phase': 'Traction',
#   'topics': ['construcción', 'Inteligencia Artificial'],
#   'description': 'Controla riesgos sobre procesos de negocio en tiempo real',
#   'url': 'https://lanzadera.es/proyecto/beawre/',
#   'logo_link': 'https://lanzadera.es/wp-content/uploads/2023/05/Beawre_logo1_420x420.png'},
#  2: {'name': 'Sitandplug ',
#   'phase': 'Growth',
#   'topics': ['Digital', 'Software'],
#   'description': 'Sitandplug es un marketplace de oficinas y espacios de trabajo flexibles con…',
#   'url': 'https://lanzadera.es/proyecto/sitandplug/',
# ...
