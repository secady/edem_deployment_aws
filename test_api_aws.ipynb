# %%
import requests

url = "http://16.16.80.161/get_db_students"

payload = {}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# [{"age":19,"category":["Finance and Investment"],"category_id":[1],"email":"doroteazapata@edem.es","gender":"female","name":"Dorotea","programme":"BBA in Business Administration","student_id":1,"surname":"Zapata","year":"4th year"},{"age":18,"category":["Management Skills","Marketing","Finance and Investment"],"category_id":[2,5,1],"email":"leiremadrid@edem.es","gender":"female","name":"Leire","programme":"BSc in Engineering and Management","student_id":2,"surname":"Madrid","year":"1st year"},{"age":18,"category":["Marketing"],"category_id":[5],"email":"guiomarcasta\u00f1eda@edem.es","gender":"female","name":"Guiomar","programme":"BBA in Business Administration","student_id":3,"surname":"Casta\u00f1eda","year":"1st year"},{"age":18,"category":["Marketing"],"category_id":[5],"email":"patriciolarrea@edem.es","gender":"male","name":"Patricio","programme":"BSc in Engineering and Management","student_id":4,"surname":"Larrea","year":"4th year"},{"age":27,"category":["Finance and Investment
# ...
