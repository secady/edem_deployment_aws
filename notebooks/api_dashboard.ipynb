# %%
from class_dashboard_admin_copia import AdminDashboard

# %%
url_programs = "https://edem-students-backend.vercel.app/programs/dataGetAll"

url_users = "https://edem-students-backend.vercel.app/users/dataGetAll"

headers = {"Authorization": "desafio2023"}

admin_dashboard = AdminDashboard(url_programs=url_programs, url_users=url_users, headers=headers)

# %%
admin_dashboard.fetch_data()

# %%
admin_dashboard.fetch_additional_data()

# %%
admin_dashboard.visualize_users_per_program()

# %%
admin_dashboard.visualize_users_per_gender()

# %%
admin_dashboard.visualize_users_per_year()

# %%
admin_dashboard.visualize_users_per_interest()

# %%
admin_dashboard.visualize_events_per_month()
# Out:
# c:\Users\selvi\OneDrive\SELVIE\Lifelong Learning\The Bridge - Data Science Bootcamp\DESAFIO\class_dashboard_admin_copia.py:171: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   events_per_month = events_df_stat.groupby(events_df_stat['date'].dt.to_period('M')).size()

# %%
admin_dashboard.visualize_users_per_event_category()
