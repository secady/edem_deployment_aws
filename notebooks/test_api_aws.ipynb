# %%
import requests

# %%
url = "http://13.48.25.210/"

payload = {}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
#     Welcome! To extract data, please see the following instructions:
#
#     <br><br>endpoint: '/get_db_events'
#     <br><br>endpoint: '/get_db_categories'
#     <br><br>endpoint: '/get_db_students'
#     <br><br>endpoint: '/get_scrap_startups'

# %%
url = "http://13.48.25.210/get_db_students"

payload = {}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# [{"age":19,"category":["Marketing","Sustainability","Tech","Business Management"],"category_id":[1,12,5,4],"email":"zairaverdugo@edem.es","gender":"female","name":"Zaira","programme":"BBA in Business Administration","student_id":1,"surname":"Verdugo","year":"4"},{"age":18,"category":["Tech","Sustainability","Finance and Investment","Networking","HR","Sport","Music","Artificial Intelligence"],"category_id":[5,12,2,11,15,9,14,7],"email":"purificaci\u00f3nllanos@edem.es","gender":"female","name":"Purificaci\u00f3n","programme":"BSc in Engineering and Management","student_id":2,"surname":"Llanos","year":"1"},{"age":18,"category":["Marketing","Finance and Investment"],"category_id":[1,2],"email":"soledadpalomares@edem.es","gender":"female","name":"Soledad","programme":"BBA in Business Administration","student_id":3,"surname":"Palomares","year":"1"},{"age":18,"category":["Crypto","Sport","Economy","Marketing","HR","Business Management","Sustainability"],"category_id":[8,9,10,1,15,4,12],"email":"jes\u00fasalberola@edem.es","gender":"male","name":"Jes\u00fas","programme":"BSc in Engineering and Management","student_id":4,"surname":"Alberola","year":"4"},{"age":27,"category":["Crypto","Employment","Economy","Tech","Marketing","Management Skills","Artificial Intelligence","Entrepreneurship","Design","Finance and Investment","Music","Networking","Sustainability","Business Management"],"category_id":[8,16,10,5,1,3,7,6,13,2,14,11,12,4],"email":"vidalbaena@edem.es","gender":"male","name":"Vidal","programme":"Master Marketing and Digital Sales","student_id":5,"surname":"Baena","year":"1"},{"age":19,"category":["Business Management","Entrepreneurship","Music","HR","Economy","Tech","Marketing","Crypto","Finance and Investment","Employment","Sustainability","Networking","Management Skills"],"category_id":[4,6,14,15,10,5,1,8,2,16,12,11,3],"email":"heraclioayll\u00f3n@edem.es","gender":"male","name":"Heraclio","programme":"BBA in Business Administration","student_id":6,"surname":"Ayll\u00f3n","year":"4"},{"age":27,"category":["Artificial Intelligence","Sustainability","Finance and Investment","Marketing","Networking","Business Management","Tech","Music","HR","Employment","Design","Crypto"],"category_id":[7,12,2,1,11,4,5,14,15,16,13,8],"email":"rodolfocontreras@edem.es","gender":"male","name":"Rodolfo","programme":"MBA Junior","student_id":7,"surname":"Contreras","year":"1"},{"age":19,"category":["HR","Networking","Music","Entrepreneurship","Management Skills","Design","Employment","Business Management","Tech"],"category_id":[15,11,14,6,3,13,16,4,5],"email":"anacletof\u00e1bregas@edem.es","gender":"male","name":"Anacleto","programme":"BSc in Engineering and Management","student_id":8,"surname":"F\u00e1bregas","year":"1"},{"age":20,"category":["Entrepreneurship","Sport","Sustainability"],"category_id":[6,9,12],"email":"bonifaciocrespi@edem.es","gender":"male","name":"Bonifacio","programme":"BBA in Business Administration","student_id":9,"surname":"Crespi","year":"2"},{"age":18,"category":["Entrepreneurship","Crypto","Artificial Intelligence","Tech","Networking","Sport","Business Management","Employment"],"category_id":[6,8,7,5,11,9,4,16],"email":"jos\u00e9luisamador@edem.es","gender":"male","name":"Jos\u00e9 Luis","programme":"BSc in Engineering and Management","student_id":10,"surname":"Amador","year":"1"},{"age":18,"category":["Crypto","Music"],"category_id":[8,14],"email":"severoandrade@edem.es","gender":"male","name":"Severo","programme":"BSc in Engineering and Management","student_id":11,"surname":"Andrade","year":"4"},{"age":18,"category":["Networking","Artificial Intelligence"],"category_id":[11,7],"email":"perlarey@edem.es","gender":"female","name":"Perla","programme":"BBA in Business Administration","student_id":12,"surname":"Rey","year":"2"},{"age":18,"category":["Management Skills","Business Management","Economy","Sustainability","Entrepreneurship","HR","Crypto","Artificial Intelligence","Music"],"category_id":[3,4,10,12,6,15,8,7,14],"em ...

# %%
url = "http://13.48.25.210/get_db_categories"

payload = {}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# [{"category_id":1,"name":"Marketing"},{"category_id":2,"name":"Finance and Investment"},{"category_id":3,"name":"Management Skills"},{"category_id":4,"name":"Business Management"},{"category_id":5,"name":"Tech"},{"category_id":6,"name":"Entrepreneurship"},{"category_id":7,"name":"Artificial Intelligence"},{"category_id":8,"name":"Crypto"},{"category_id":9,"name":"Sport"},{"category_id":10,"name":"Economy"},{"category_id":11,"name":"Networking"},{"category_id":12,"name":"Sustainability"},{"category_id":13,"name":"Design"},{"category_id":14,"name":"Music"},{"category_id":15,"name":"HR"},{"category_id":16,"name":"Employment"}]

# %%
url = "http://13.48.25.210/get_db_events"

payload = {}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# [{"category_id":2,"date":"Thu, 22 Jun 2023 00:00:00 GMT","description":"empty","event_id":1,"title":"HR INTERNATIONAL SUMMER SCHOOL"},{"category_id":3,"date":"Tue, 04 Jul 2023 19:00:00 GMT","description":"empty","event_id":2,"title":"OPEN DAY BOOTCAMPS EDEM POWERED BY THE BRIDGE"},{"category_id":1,"date":"Mon, 05 Jun 2023 11:30:00 GMT","description":"empty","event_id":3,"title":"ENCUENTRO CON ERIC MASKIN, PREMIO NOBEL DE ECONOM\u00cdA 2007"}]

# %%
url = "http://13.48.25.210/get_scrap_startups"

payload = {}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"description":{"0":"Mytapper permite pedir comida desde casa o desde el propio restaurante.","1":"Controla riesgos sobre procesos de negocio en tiempo real","10":"Follow Inspiration es una empresa especializada en robots de navegaci\u00f3n aut\u00f3noma.","100":"GUZZU impulsa el merchandising digital en la industria musical a trav\u00e9s de\u2026","101":"Digitalizaci\u00f3n de la cadena de suministro utilizando IoT, AI y Blockchain","102":"DeleiteWear es la primera soluci\u00f3n circular que viste a los hoteles con\u2026","103":"Todo lo que necesitas para dirigir tu negocio online en un solo\u2026","104":"VRi lleva la medicina a una nueva dimensi\u00f3n","105":"Mas Leads genera nuevas oportunidades de negocio utilizando la IA.","106":"Edificios Inteligentes Aut\u00f3nomos","107":"Dotando de eficiencia y rentabilidad los esfuerzos en ESG (Environmental, Social and\u2026","108":"Plataforma inmobiliaria para crear viviendas personalizadas, sostenibles y accesibles.","109":"Transforma las organizaciones a trav\u00e9s del cambio de mentalidad de las personas","11":"Cambiando la forma de inversi\u00f3n en Energ\u00eda Renovable","110":"Aprende a tocar tus canciones favoritas con los artistas originales","111":"Cantina inteligente para oficinas operada por restaurantes y caterings de proximidad","112":"Plataforma m\u00f3vil que permite a cualquier persona crear, compartir, monetizar y vivir\u2026","113":"Hardman es una torre de control log\u00edstica con capacidad de gesti\u00f3n","114":"Anticipa f\u00e1cilmente el comportamiento de tus clientes con el uso de la\u2026","115":"Innovaci\u00f3n en el sector del contenedor","116":"Extrae todo el valor a la inteligencia artificial","117":"Mundo virtual web3 construido por creadores","118":"Generative AI aplicada a la psicolog\u00eda","119":"Rentastic es la plataforma de renting industrial sin intereses","12":"Plataforma SaaS de pedidos y entregas digitales para cadenas de restaurantes medianas\u2026","120":"Solved es un software que permite optimizar la gesti\u00f3n de incidencias de\u2026","121":"Inteligencia Artificial asequible, pr\u00e1ctica y comprensible para resolver los problemas del sector\u2026","122":"Crean comunidades solares en cualquier tejado, ayudando a ahorrar a vecinos y\u2026","123":"Plataforma de metaverso industrial para la gesti\u00f3n y optimizaci\u00f3n de operaciones avanzadas","124":"Getlinko es un marketplace que conecta a webs, blogs, peri\u00f3dicos digitales y\u2026","125":"Reservar un alojamiento de forma f\u00e1cil y segura","126":"Virtuleap combina neurociencia y realidad virtual para aumentar los niveles de atenci\u00f3n\u2026","127":"Plataforma de Embedded Analytics para empresas de software y SaaS","128":"Realidad Virtual para la planificaci\u00f3n quir\u00fargica compleja","129":"Una visi\u00f3n completa de la salud estructural de los puentes","13":"IA que matchea cultura y valores entre empresas y personas","130":"SaaS de gesti\u00f3n de siniestros","131":"La aplicaci\u00f3n y comunidad online para el entrenamiento.","132":"Robots aut\u00f3nomos para inspecciones industriales","133":"El marketplace de referencia en moda emergente para j\u00f3venes","134":"Software para optimizar el consumo energ\u00e9tico de los hogares","135":"Software de gesti\u00f3n para abogados - Tecnolog\u00eda al servicio de la abogac\u00eda","136":"King Brown es la recreaci\u00f3n de los brownies tradicionales.","137":"Neroes mejora la salud mental y el rendimiento con neurotecnolog\u00edas avanzadas","138":"Marketplace que conecta a creadores y empresas con artistas de voz de\u2026","139":"Saas de predicci\u00f3n de personalidad","14":"Lever.tax desbloquea cr\u00e9ditos fiscales para empresas innovadoras","140":"Plataforma de simulaci\u00f3n en la nube","141":"","142":"","143":"Soluciones digitales y an\u00e1lisis de datos para organizaciones deportivas","144":"","145":"Plataforma e-learning para bachillerato y selectividad","146":"Educaci\u00f3n adaptativa, el futuro de la  ...
